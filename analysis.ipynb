# %%
from IPython.display import HTML as display_html
import numpy as np
import pandas as pd
from wmfdata import hive, utils
from wmfdata.utils import num_str

# %% [markdown]
# We have clean, complete data in EditAttemptStep starting on 8 February 2019 and we started oversampling mobile visual editor events 2019-03-06T00:23:49Z (https://phabricator.wikimedia.org/T212253).

# %%
display_html("""
<script>  
    code_show=true; 
    function code_toggle() {
        if (code_show){
            $(\'div.input\').hide();
        } else {
            $(\'div.input\').show();
        }
        code_show = !code_show
    }  
// $( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()">
    <input type="submit" value="Click here to toggle on/off the raw code.">
</form>
""")
# Out:
# <script>
#     code_show=true;
#     function code_toggle() {
#         if (code_show){
#             $('div.input').hide();
#         } else {
#             $('div.input').show();
#         }
#         code_show = !code_show
#     }
# // $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()">
#     <input type="submit" value="Click here to toggle on/off the raw code.">
# </form>

# %% [markdown]
# # Attempts and completion by interface and experience

# %%
attempts = hive.run("""
-- Transform the steps into attempts
with steps as (
    select
        event.editing_session_id as attempt_id,
        unix_timestamp(
            dt,
            "yyyy-MM-dd'T'hh:mm:ssX"
        ) as ts,
        wiki,
        database_group,
        event.platform as platform,
        event.editor_interface as interface,
        event.action as action,
        event.is_oversample as is_oversample,
        event.user_editcount as user_edit_count,
        coalesce(event.user_class = "IP", False) as user_is_unregistered
    from event_sanitized.editattemptstep
    left join canonical_data.wikis
    on wiki = database_code
    where
        -- Remove Flow and other non-standard edits
        event.integration = "page" and
        -- Remove events not needed to calculate session starts or completions
        event.action in ("ready", "saveSuccess") and
        -- One month of data
        year = 2019 and (
            (month = 5 and day >= 17) or
            (month = 6 and day < 16)
        )
    -- Ensure that steps within each session are in chronological order without having to do a global order by
    distribute by attempt_id
    sort by ts asc
)
-- Group those steps into attempts
select
    attempt_id,
    from_unixtime(min(ts), "yyyy-MM-dd'T'hh:mm:ssX") as dt,
    min(wiki) as wiki,
    case
        when min(database_group) != "wikipedia" then Null
        when min(wiki) in ("enwiki", "nlwiki", "eswiki") then False
        else True
    end as ve_default_wiki,
    min(platform) as platform,
    -- Select the last editor in the session as the "real" one
    collect_list(interface)[
        size(collect_list(interface)) - 1
    ] as editor,
    sum(cast(action = "saveSuccess" as int)) >= 1 as is_completed,
    max(is_oversample) as is_oversample,
    case
        when max(user_is_unregistered) or max(user_edit_count) is null then "unregistered"
        when max(user_edit_count) = 0 then "0"
        when max(user_edit_count) < 5 then "1-4"
        when max(user_edit_count) < 100 then "5-99"
        when max(user_edit_count) < 1000 then "100-999"
        when max(user_edit_count) < 10000 then "1000-9999"
        else "10000+"
    end as user_experience
from steps        
group by attempt_id
""").assign(
    dt=lambda df: pd.to_datetime(df["dt"]),
    wiki=lambda df: pd.Categorical(df["wiki"]),
    platform=lambda df: pd.Categorical(df["platform"]),
    editor=lambda df: pd.Categorical(df["editor"]),
    user_experience=lambda df: pd.Categorical(
        df["user_experience"],
        categories=["unregistered", "0", "1-4", "5-99", "100-999", "1000-9999", "10000+"], ordered=True
    )
)

# %% [markdown]
# ## Average daily edit attempts

# %%
(
    attempts
    .query("~is_oversample")
    .groupby(["platform", "editor", "user_experience"])
    .apply(len)
    .unstack().T
    .multiply((16/30)) # Correct for sampling, reduce to daily average
    .style
    .background_gradient(axis=None)
    .format(lambda x: num_str(int(x)))
)
# Out:
# <style  type="text/css" >
#     #T_9cf62566_9079_11e9_bf06_d094661b49a6row0_col0 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row0_col1 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row0_col3 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row1_col1 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row1_col4 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row2_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row3_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row3_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row3_col4 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row4_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row4_col1 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row4_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row4_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row4_col4 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row5_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row5_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row5_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row5_col4 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row6_col1 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_9cf62566_9079_11e9_bf06_d094661b49a6row6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_9cf62566_9079_11e9_bf06_d094661b49a6" ><thead>    <tr>        <th class="index_name level0" >platform</th>        <th class="col_heading level0 col0" colspan=3>desktop</th>        <th class="col_heading level0 col3" colspan=2>phone</th>    </tr>    <tr>        <th class="index_name level1" >editor</th>        <th class="col_heading level1 col0" >visualeditor</th>        <th class="col_heading level1 col1" >wikitext</th>        <th class="col_heading level1 col2" >wikitext-2017</th>        <th class="col_heading level1 col3" >visualeditor</th>        <th class="col_heading level1 col4" >wikitext</th>    </tr>    <tr>        <th class="index_name level0" >user_experience</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9cf62566_9079_11e9_bf06_d094661b49a6level0_row0" class="row_heading level0 row0" >unregistered</th>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row0_col0" class="data row0 col0" >170,000</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row0_col1" class="data row0 col1" >390,000</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row0_col2" class="data row0 col2" >9</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row0_col3" class="data row0 col3" >7,900</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row0_col4" class="data row0 col4" >1,100,000</td>
#             </tr>
#             <tr>
#                         <th id="T_9cf62566_9079_11e9_bf06_d094661b49a6level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row1_col0" class="data row1 col0" >4,000</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row1_col1" class="data row1 col1" >8,400</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row1_col2" class="data row1 col2" >56</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row1_col3" class="data row1 col3" >960</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row1_col4" class="data row1 col4" >4,300</td>
#             </tr>
#             <tr>
#                         <th id="T_9cf62566_9079_11e9_bf06_d094661b49a6level0_row2" class="row_heading level0 row2" >1-4</th>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row2_col0" class="data row2 col0" >3,600</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row2_col1" class="data row2 col1" >8,100</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row2_col2" class="data row2 col2" >94</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row2_col3" class="data row2 col3" >1,300</td>
#                         <td id="T_9cf62566_9079_11e9_bf06_d094661b49a6row2_col4" class="data row2 col4" >3,500</td>
#             </tr>
#             <tr>
#                         <th id="T_9cf62566_9079_11e9_bf06_d094661b49a6level0_row3" class="row_heading level0 row3" >5-99</th>
#                         <td id="T_9cf62566_9079_11e9_bf06_d09

# %% [markdown]
# ## Completion rates

# %%
completion_rates = (
    attempts
    .groupby(["platform", "editor", "user_experience"])
    .apply(lambda grp: grp["is_completed"].sum() / len(grp))
    .unstack()
    .T
)

(
    completion_rates
    .style
    .background_gradient(axis=None)
    .format("{:.0%}")
)
# Out:
# <style  type="text/css" >
#     #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row0_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row0_col1 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row0_col3 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row0_col4 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row1_col0 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row1_col1 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row1_col2 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row1_col3 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row1_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row2_col0 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row2_col1 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row2_col2 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row2_col3 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row2_col4 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row3_col0 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row3_col1 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row3_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row3_col3 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row3_col4 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row4_col0 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row4_col1 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row4_col2 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row4_col3 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row4_col4 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row5_col0 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row5_col1 {
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row5_col2 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row5_col3 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row5_col4 {
#             background-color:  #197db7;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row6_col0 {
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row6_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row6_col2 {
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row6_col3 {
#             background-color:  #167bb6;
#             color:  #000000;
#         }    #T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row6_col4 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }</style><table id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6" ><thead>    <tr>        <th class="index_name level0" >platform</th>        <th class="col_heading level0 col0" colspan=3>desktop</th>        <th class="col_heading level0 col3" colspan=2>phone</th>    </tr>    <tr>        <th class="index_name level1" >editor</th>        <th class="col_heading level1 col0" >visualeditor</th>        <th class="col_heading level1 col1" >wikitext</th>        <th class="col_heading level1 col2" >wikitext-2017</th>        <th class="col_heading level1 col3" >visualeditor</th>        <th class="col_heading level1 col4" >wikitext</th>    </tr>    <tr>        <th class="index_name level0" >user_experience</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6level0_row0" class="row_heading level0 row0" >unregistered</th>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row0_col0" class="data row0 col0" >4%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row0_col1" class="data row0 col1" >10%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row0_col2" class="data row0 col2" >0%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row0_col3" class="data row0 col3" >22%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row0_col4" class="data row0 col4" >2%</td>
#             </tr>
#             <tr>
#                         <th id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row1_col0" class="data row1 col0" >27%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row1_col1" class="data row1 col1" >20%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row1_col2" class="data row1 col2" >10%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row1_col3" class="data row1 col3" >27%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row1_col4" class="data row1 col4" >22%</td>
#             </tr>
#             <tr>
#                         <th id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6level0_row2" class="row_heading level0 row2" >1-4</th>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row2_col0" class="data row2 col0" >43%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row2_col1" class="data row2 col1" >38%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row2_col2" class="data row2 col2" >19%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row2_col3" class="data row2 col3" >32%</td>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row2_col4" class="data row2 col4" >31%</td>
#             </tr>
#             <tr>
#                         <th id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6level0_row3" class="row_heading level0 row3" >5-99</th>
#                         <td id="T_ac2fcbaa_9078_11e9_bf06_d094661b49a6row3_col0" class="da

# %% [markdown]
# # Desktop completion rate by interface, experience, and VE default status

# %%
(
    attempts
    .query("platform == 'desktop' & editor == 'visualeditor' & ~ve_default_wiki.isnull()")
    .groupby(["ve_default_wiki", "user_experience"])
    .apply(lambda grp: grp["is_completed"].sum() / len(grp))
    .unstack()
    .transpose()
    .join(completion_rates[("desktop", "wikitext")].rename("wikitext"))
    .rename(columns={
        False: "visualeditor (non-default wiki)", 
        True: "visualeditor (default wiki)"
    })
    .rename_axis(None, axis=1)
    .style
    .background_gradient(axis=None)
    .format("{:.0%}")
)
# Out:
# <style  type="text/css" >
#     #T_4493533a_9079_11e9_bf06_d094661b49a6row0_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row0_col2 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row1_col0 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row1_col1 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row1_col2 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row2_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row2_col1 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row2_col2 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row3_col0 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row3_col1 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row3_col2 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row4_col0 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row4_col1 {
#             background-color:  #056aa6;
#             color:  #f1f1f1;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row4_col2 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row5_col0 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row5_col1 {
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row5_col2 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row6_col0 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row6_col1 {
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }    #T_4493533a_9079_11e9_bf06_d094661b49a6row6_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_4493533a_9079_11e9_bf06_d094661b49a6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >visualeditor (non-default wiki)</th>        <th class="col_heading level0 col1" >visualeditor (default wiki)</th>        <th class="col_heading level0 col2" >wikitext</th>    </tr>    <tr>        <th class="index_name level0" >user_experience</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4493533a_9079_11e9_bf06_d094661b49a6level0_row0" class="row_heading level0 row0" >unregistered</th>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row0_col0" class="data row0 col0" >8%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row0_col1" class="data row0 col1" >4%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row0_col2" class="data row0 col2" >10%</td>
#             </tr>
#             <tr>
#                         <th id="T_4493533a_9079_11e9_bf06_d094661b49a6level0_row1" class="row_heading level0 row1" >0</th>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row1_col0" class="data row1 col0" >31%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row1_col1" class="data row1 col1" >26%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row1_col2" class="data row1 col2" >20%</td>
#             </tr>
#             <tr>
#                         <th id="T_4493533a_9079_11e9_bf06_d094661b49a6level0_row2" class="row_heading level0 row2" >1-4</th>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row2_col0" class="data row2 col0" >47%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row2_col1" class="data row2 col1" >41%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row2_col2" class="data row2 col2" >38%</td>
#             </tr>
#             <tr>
#                         <th id="T_4493533a_9079_11e9_bf06_d094661b49a6level0_row3" class="row_heading level0 row3" >5-99</th>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row3_col0" class="data row3 col0" >54%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row3_col1" class="data row3 col1" >54%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row3_col2" class="data row3 col2" >53%</td>
#             </tr>
#             <tr>
#                         <th id="T_4493533a_9079_11e9_bf06_d094661b49a6level0_row4" class="row_heading level0 row4" >100-999</th>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row4_col0" class="data row4 col0" >62%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row4_col1" class="data row4 col1" >65%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row4_col2" class="data row4 col2" >66%</td>
#             </tr>
#             <tr>
#                         <th id="T_4493533a_9079_11e9_bf06_d094661b49a6level0_row5" class="row_heading level0 row5" >1000-9999</th>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row5_col0" class="data row5 col0" >67%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row5_col1" class="data row5 col1" >69%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row5_col2" class="data row5 col2" >74%</td>
#             </tr>
#             <tr>
#                         <th id="T_4493533a_9079_11e9_bf06_d094661b49a6level0_row6" class="row_heading level0 row6" >10000+</th>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row6_col0" class="data row6 col0" >77%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row6_col1" class="data row6 col1" >75%</td>
#                         <td id="T_4493533a_9079_11e9_bf06_d094661b49a6row6_col2" class="data row6 col2" >82%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # User agent breakdown
#
# Has to be computed separately, because user agent info isn't included in the `event_santitized` database.

# %%
hive.run("""
select
    useragent.browser_family,
    useragent.device_family,
    useragent.os_family
from event.editattemptstep
where year = 2019 and month = 6 and day = 16 and hour = 1
limit 50
""")
